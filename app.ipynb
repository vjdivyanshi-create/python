# %%
print("hello","python", sep="-", end="!")
print("""
yooooooooooo
ooooooo
ooooooo""")
# Out:
# hello-python!
# yooooooooooo
# ooooooo
# ooooooo

# %%
a ="this is python"
print(type(a))
a = 10
print(a, type(a))
# Out:
# <class 'str'>
# 10 <class 'int'>

# %%
a = 10
b = 10.0
print(id(b))
print(id(a))
# Out:
# 1445041850160
# 140732114453912

# %%
n1 = int(input("enter your number:"))
print(n1 , type(n1))
# Out:
# 753 <class 'int'>

# %%
price = 280
tax =18
print(f"this price is {price*tax/100 + price} rupees")
# Out:
# this price is 330.4 rupees

# %%
x = int(20)
print(type(x))
# Out:
# <class 'int'>

# %%
a = "\tHEllo "
b = "divyaNshi "
# print(a+b)
# print(b.upper())
print(b.title())
print(b.capitalize())
# print(a.center(60))
# print(b.count("i"))
# print(a.expandtabs(tabsize=20))
# print(a.index("l"))
# print(a.isalpha())
# Out:
# Divyanshi
# Divyanshi

# %%
s = "-"
seq = ("a","b","c")
print(s.join(seq))
a = "PYTHON"
print(a.rjust(60))
print(a.lstrip("H"))
print(a.replace("T","gfdghc"))
# Out:
# a-b-c
#                                                       PYTHON
# PYTHON
# PYgfdghcHON

# %%
l = "rtpon"
e = "12345"
str = "this is python!!!"
encoding = str.maketrans(l,e)
print(str.translate(encoding))
# Out:
# 2his is 3y2h45!!!

# %%
a = "this is python"
b = "this"
if(b not in a):
    print("b is not a substring of a.")
else:
    print("b is sub string of a.")
# Out:
# b is sub string of a.

# %%
a = 17
if(a>10):
    print("a is greater than 10")
    print(a)
else:
    print("a is less than or equal to 10")
# Out:
# a is greater than 10
# 17

# %%
n = 9
print("n is greater than 10") if(n>10) else print("n is less then or equals to 10")
# Out:
# n is less then or equals to 10

# %%
for i in range(5):
    print(i)
for i in range (-5,5,1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# -5
# -4
# -3
# -2
# -1
# 0
# 1
# 2
# 3
# 4

# %%
number = input("enter a number:")
for i in range(1,11):
    print(number,"X", i ,"= ", int(number)*i)
# Out:
# 7 X 1 =  7
# 7 X 2 =  14
# 7 X 3 =  21
# 7 X 4 =  28
# 7 X 5 =  35
# 7 X 6 =  42
# 7 X 7 =  49
# 7 X 8 =  56
# 7 X 9 =  63
# 7 X 10 =  70

# %%
for i in range(5,0,-1):
    for j in range(5):
        print(i,j, sep="--")
# Out:
# 5--0
# 5--1
# 5--2
# 5--3
# 5--4
# 4--0
# 4--1
# 4--2
# 4--3
# 4--4
# 3--0
# 3--1
# 3--2
# 3--3
# 3--4
# 2--0
# 2--1
# 2--2
# 2--3
# 2--4
# 1--0
# 1--1
# 1--2
# 1--3
# 1--4

# %%
c = "y"
while(c!="x"):
    c = input("enter a character:")
    print("you entered", c)
# Out:
# you entered
# you entered hgygk
# you entered jlmm
# you entered njkb
# you entered xzfdga
# you entered x

# %%
str = "python is language"
print(str[-7])
print(str[0:10:2])
print(str[0::3])
for i in str:
    print(i)

print("lenght of sting is:",len(str))

print(ord("a"))
print(chr(97))
# Out:
# a
# pto s
# ph  na
# p
# y
# t
# h
# o
# n
#
# i
# s
#
# l
# a
# n
# g
# u
# a
# g
# e
# lenght of sting is: 18
# 97
# a

# %%
marks = input("enter your marks:")
if(int(marks)>90):
    print("grade is A")
elif(int(marks)>75):
    print("grade is B")
elif(int(marks)>50):
    print("grade is C")
else:
    print("grade is D")
# Out:
# grade is B

# %%
l = [10,20,30,40,50]
l2 = ["a",60,"b","c",30,"d"]
print(l2[0:4],type(l2))

for x in l2:
    print(x)
# Out:
# ['a', 60, 'b', 'c'] <class 'list'>
# a
# 60
# b
# c
# 30
# d

# %%
list=[11,82,23,81,54,64,21,80,99,10]
for i in range(10,0,-1):
    print(list[i-1])

sum = 0
for i in list:
    sum = sum + i
print(sum, "is the sum of list")

min = list[0]
for i in list:
    if(i<min):
        min = i

print(min, "is the minimum number in list")
# Out:
# 10
# 99
# 80
# 21
# 64
# 54
# 81
# 23
# 82
# 11
# 525 is the sum of list
# 10 is the minimum number in list

# %%
str = "this is python"
l = str.split()
print(l)
# Out:
# ['this', 'is', 'python']

# %%
list = []
print(list)
list.append(10)
list.append(20) 
print(list)
# Out:
# []
# [10, 20]

# %%
str = "this is python" 
l = str.split()
l2 = [20,30,40,50,60,70]
#l.append(l2)
print(l)
#print(l[3][4])

l.extend(l2)
l.remove(40)
print(l)

l.pop()
print(l)
# Out:
# ['this', 'is', 'python']
# ['this', 'is', 'python', 20, 30, 50, 60, 70]
# ['this', 'is', 'python', 20, 30, 50, 60]

# %%
# num = [10,20,30,40,50]
# sum = sum(num)
# print(sum)
# sum = sum(num,10)
# print(sum)

# %%
d = {1:"python", 
     2:"java", 
     3:"c++"
     }
print(d)
# Out:
# {1: 'python', 2: 'java', 3: 'c++'}
