# %%
import pandas as pd
import numpy as np

# %%
print(pd.date_range('05/28/2026',periods=10))
# Out:
# DatetimeIndex(['2026-05-28', '2026-05-29', '2026-05-30', '2026-05-31',
#                '2026-06-01', '2026-06-02', '2026-06-03', '2026-06-04',
#                '2026-06-05', '2026-06-06'],
#               dtype='datetime64[us]', freq='D')

# %%
df = pd.read_csv("tips.csv")
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(df['time'])
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: str

# %%
res = df[df['total_bill']>40]
print(res)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
print(df['day'].value_counts())
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
# df = pd.read_json("tips.json")
# print(df.head())

# %%
df = pd.read_csv("tips.csv")
print(df.to_string)

df.fillna({'total_bill': 0,'time':'-'}, inplace=True)
print(df)
# Out:
# <bound method DataFrame.to_string of      total_bill   tip     sex smoker   day    time  size
# 0           NaN  1.01  Female     No   Sun  Dinner     2
# 1           NaN  1.66    Male     No   Sun  Dinner     3
# 2           NaN  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>
#      total_bill   tip     sex smoker   day    time  size
# 0          0.00  1.01  Female     No   Sun  Dinner     2
# 1          0.00  1.66    Male     No   Sun  Dinner     3
# ...

# %%
df= pd.read_csv("tips.csv")
x = df['total_bill'].mean()
df.fillna({'total_bill': x,'time':'-'}, inplace=True)
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0      19.83166  1.01  Female     No   Sun  Dinner     2
# 1      19.83166  1.66    Male     No   Sun  Dinner     3
# 2      19.83166  3.50    Male     No   Sun  Dinner     3
# 3      23.68000  3.31    Male     No   Sun  Dinner     2
# 4      24.59000  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239    29.03000  5.92    Male     No   Sat  Dinner     3
# 240    27.18000  2.00  Female    Yes   Sat  Dinner     2
# 241    22.67000  2.00    Male    Yes   Sat  Dinner     2
# 242    17.82000  1.75    Male     No   Sat  Dinner     2
# 243    18.78000  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df= pd.read_csv("tips.csv")
x = df['total_bill'].median()
df.fillna({'total_bill': x,'time':'-'}, inplace=True)
print(df)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         17.81  1.01  Female     No   Sun  Dinner     2
# 1         17.81  1.66    Male     No   Sun  Dinner     3
# 2         17.81  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
