# %%
import pandas as pd

# %%
data = [10,20,30,40,50]

ps = pd.Series(data, index = ['a','b','c','d','e'], dtype = "float", name = "Integer series")
print(ps)
print(type(ps))
# Out:
# a    10.0
# b    20.0
# c    30.0
# d    40.0
# e    50.0
# Name: Integer series, dtype: float64
# <class 'pandas.Series'>

# %%
data2 = {
    "subject":['python','java','c++'],
    "marks":[85,90,92]
}

df = pd .DataFrame(data2)
print(df)
print(type(df))

print(pd.__version__)
# Out:
#   subject  marks
# 0  python     85
# 1    java     90
# 2     c++     92
# <class 'pandas.DataFrame'>
# 3.0.3

# %%
data = [90,82,78,45,77]
df= pd.Series(data, index = ['a','b','c','d','e'])
print(df)
print(df[2])
print(df[1:3])
print(type(df))

# %%
data3 = {
    'day1':[400,500], 'day2':440
}
df2 = pd.Series(data3)
print(df2)
res=df2.tolist()
print(res)
# Out:
# day1    [400, 500]
# day2           440
# dtype: object
# [[400, 500], 440]

# %%
data4 = {
    "qmarks":[85,66,92],
    "duration":[2,1,3]
}
df3= pd.DataFrame(data4)
print(df3.loc[[0]])
print(df3.loc[[0,1,2]])
# Out:
#    qmarks  duration
# 0      85         2
#    qmarks  duration
# 0      85         2
# 1      66         1
# 2      92         3

# %%
data4 = {
    "qmarks":[85,66,92],
    "duration":[2,1,3]
}
df3= pd.DataFrame(data4)
print(df3)
df3.index = ['a','b','c']
print(df3)
# Out:
#    qmarks  duration
# 0      85         2
# 1      66         1
# 2      92         3
#    qmarks  duration
# a      85         2
# b      66         1
# c      92         3

# %%
data4 = {
    "sub":['python','java','c++'],
    "qmarks":[85,66,92],
    "dur":[2,1,3]
}
df= pd.DataFrame(data4)
print(df)
df.columns = ['subject','marks','duration']
result = df.columns
print(result)
print(df)
# Out:
#       sub  qmarks  dur
# 0  python      85    2
# 1    java      66    1
# 2     c++      92    3
# Index(['subject', 'marks', 'duration'], dtype='str')
#   subject  marks  duration
# 0  python     85         2
# 1    java     66         1
# 2     c++     92         3

# %%
df = pd.DataFrame([['a','b',10,20],['c','d',30,40],['e','f',20,50],['g','h',70,48]], columns=['col1','col2','col3','col4'])
print(df)
df.index=['r1','r2','r3','r4']
res = df.loc['r1':'r2','col1':'col2']
print(res)
res1 = df.iloc[0:1,0:1]
df.iloc[1:3,0]=['x','y']
print(df)
# Out:
#   col1 col2  col3  col4
# 0    a    b    10    20
# 1    c    d    30    40
# 2    e    f    20    50
# 3    g    h    70    48
#    col1 col2
# r1    a    b
# r2    c    d
#    col1 col2  col3  col4
# r1    a    b    10    20
# r2    x    d    30    40
# r3    y    f    20    50
# r4    g    h    70    48

# %%
df = pd.DataFrame([['a','b',10,20],['c','d',30,40],['e','f',20,50],['g','h',70,48]], columns=['col1','col2','col3','col4'])
print(df)
res = df.drop(3)
print(res,"\n\n")
# drop the row with index 3

df1 = pd.DataFrame([['a','b',10,20],['c','d',30,40],['e','f',20,50],['g','h',70,48]], columns=['col1','col2','col3','col4'])
print(df1)
res = df1.drop([1,3])
print(res)
# Out:
#   col1 col2  col3  col4
# 0    a    b    10    20
# 1    c    d    30    40
# 2    e    f    20    50
# 3    g    h    70    48
#   col1 col2  col3  col4
# 0    a    b    10    20
# 1    c    d    30    40
# 2    e    f    20    50
#
#
#   col1 col2  col3  col4
# 0    a    b    10    20
# 1    c    d    30    40
# 2    e    f    20    50
# 3    g    h    70    48
#   col1 col2  col3  col4
# 0    a    b    10    20
# 2    e    f    20    50

# %%
df = pd.DataFrame({'A':[1,2,3,4,5],'B':[4,5,6,7,8],'C':[9,10,11,12,0]}, index = ['r1','r2','r3','r4','r5'])

print(df)

# drop row where columns C is 0

result = df[df["C"]!=0]
print(result,"\n")

print(result['C'])
# Out:
#     A  B   C
# r1  1  4   9
# r2  2  5  10
# r3  3  6  11
# r4  4  7  12
# r5  5  8   0
#     A  B   C
# r1  1  4   9
# r2  2  5  10
# r3  3  6  11
# r4  4  7  12
#
# r1     9
# r2    10
# r3    11
# r4    12
# Name: C, dtype: int64
