# %%
# Dictonary
student = {
    "name": "Divyanshi",
    "age": 20,
    "course": "Python"
}

print("Student Details:")
print(student)

print("Name:", student["name"])

# Adding new item
student["marks"] = 90

print("Updated Dictionary:")
print(student)
# Out:
# Student Details:
# {'name': 'Divyanshi', 'age': 20, 'course': 'Python'}
# Name: Divyanshi
# Updated Dictionary:
# {'name': 'Divyanshi', 'age': 20, 'course': 'Python', 'marks': 90}

# %%
#tuple
numbers = (10, 20, 30, 40)

print("Tuple:", numbers)

print("First Element:", numbers[0])

# Tuple length
print("Length of Tuple:", len(numbers))
# Out:
# Tuple: (10, 20, 30, 40)
# First Element: 10
# Length of Tuple: 4

# %%
# set
fruits = {"apple", "banana", "mango", "apple"}

print("Set:", fruits)

# Adding element
fruits.add("orange")

print("Updated Set:", fruits)
# Out:
# Set: {'banana', 'mango', 'apple'}
# Updated Set: {'banana', 'mango', 'orange', 'apple'}

# %%
# Function for basic math operations

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not allowed"

# Taking input from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition =", add(num1, num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", divide(num1, num2))
# Out:
# Addition = 54.0
# Subtraction = 30.0
# Multiplication = 504.0
# Division = 3.5

# %%
# Program to check palindrome number

num = int(input("Enter a number: "))

original_num = num
reverse_num = 0

# Finding reverse
while num > 0:
    digit = num % 10
    reverse_num = reverse_num * 10 + digit
    num = num // 10

print("Reverse Number =", reverse_num)

# Checking palindrome
if original_num == reverse_num:
    print("It is a Palindrome Number")
else:
    print("It is NOT a Palindrome Number")
# Out:
# Reverse Number = 12321
# It is a Palindrome Number
