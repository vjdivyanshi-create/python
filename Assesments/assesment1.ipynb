# %%
import pandas as pd

# %%
# 1) Practice print() Statement
#a) Print with multiple objects
name = "Divyanshi"
age = 20

print("Name:", name, "Age:", age)

# b) Print with sep (separator)
print("Python", "Java", "C++", sep=" | ")

#c) Print with end
print("Hello", end=" ")
print("World")
# Out:
# Name: Divyanshi Age: 20
# Python | Java | C++
# Hello World

# %%
# 2) Ask User to Enter Name and Display Greeting Message
name = input("Enter your name: ")

print("Hello,", name + "!", "Welcome to Python Programming.")
# Out:
# Hello, divyanshi! Welcome to Python Programming.
